# %%
from sklearn.datasets import load_iris

# %%
import pandas as pd

# %%
iris=load_iris()

# %%
x=iris.data[:50,0]
y=iris.data[:50,1]
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %%
datasets=pd.DataFrame(iris.data,columns=iris.feature_names)
datasets['target']=iris.target

# %%
datasets
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
import numpy as np

# %%
x=x.reshape(-1,1)
y=y.reshape(-1,1)

# %%
once=np.ones((x.shape[0],1))
X_b=np.concatenate((once,x),axis=1) # add bias term
theta_best=np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)  # normal equation
theta_best  # theta0 and theta1 
# Predicting values
X_new=np.array([[0],[7]])   # new data for prediction   
X_new_b=np.concatenate((np.ones((X_new.shape[0],1)),X_new),axis=1) # add bias term
y_predict=X_new_b.dot(theta_best)               
y_predict
plt.plot(X_new,y_predict,'r-')  
plt.scatter(x,y)
plt.xlabel('Sepal length')
# Out:
# Text(0.5, 0, 'Sepal length')
